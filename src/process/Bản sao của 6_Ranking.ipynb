# %% [markdown]
#     Score = a * score_OTAs - b * price + c * review_score

# %% [markdown]
#     id_hotel    : id của khách sạn trong database
#     rate_mean   : điểm rating trung bình của khách sạn theo các domain
#     review_mean : điểm review trung bình của khách sạn theo các domain
#     price_min   : giá thấp nhất

# %% [markdown]
# # Setup

# %%
import pandas as pd

# %%
dir = '/content/drive/MyDrive/HUST/20202/Tích hợp dữ liệu/data/hotel_info.csv'

hotel_info = pd.read_csv(dir)
hotel_info.T
# Out:
#                                                              0    ...                                                469
# name           RedDoorz ở Đường Phạm Ngũ Lão 3 (RedDoorz @ Ph...  ...  Khách sạn Lenid De Hồ Gươm\n(Lenid De Ho Guom ...
# img_url        ['https://cf.bstatic.com/images/hotel/max1024x...  ...  https://pix5.agoda.net/hotelImages/246/246345/...
# url1           https://www.booking.com/hotel/vn/nam-long.vi.html  ...                                                NaN
# url2           https://www.agoda.com/vi-vn/new-legend-hotel/h...  ...  https://www.agoda.com/vi-vn/lenid-de-ho-guom-h...
# url3                                                         NaN  ...                                                NaN
# url4                                                         NaN  ...  https://www.traveloka.com/vi-vn/hotel/vietnam/...
# city                                                           3  ...                                                  1
# address        283/3 Pham Ngu Lao str, Quận 1, Hồ Chí Minh, V...  ...  38 Hai Bà Trưng, Tràng Tiền, Quận Hoàn Kiếm, ...
# description    Nam Long Hotel chỉ cách Trung tâm Thành phố Hồ...  ...  ['Vị trí\nLưu trú tại Lenid De Ho Guom Hotel l...
# stars                                                          2  ...                                                  3
# price                                                     248182  ...                                             519481
# rating                                                       7.8  ...                                                8.5
# number_review                                                 56  ...                                                117
# nearby_places  ['The Independence Palace - 1,06 km', 'A O Sho...  ...  ['Tràng Tiền Plaza', 'Hanoi Train Street', 'Go...
# facilities     ['Nằm ở trung tâm Hồ Chí Minh', 'Đưa đón sân b...  ...  ['Máy lạnh', 'Nhà hàng', 'Lễ tân 24h', 'Thang ...
# slug                            reddoorz_o_duong_pham_ngu_lao_3_  ...                       khach_san_lenid_de_ho_guom\n
#
# [16 rows x 470 columns]

# %% [markdown]
# # Get important features

# %%
cols = ['name', 'stars', 'price', 'rating', 'number_review']

basic_info = hotel_info[cols]
basic_info.reset_index(drop=True, inplace=True)
basic_info
# Out:
#                                                   name  ...  number_review
# 0    RedDoorz ở Đường Phạm Ngũ Lão 3 (RedDoorz @ Ph...  ...           56.0
# 1                            OYO 520 Friendly Homestay  ...          148.0
# 2                        RedDoorz @ Nguyen Kiem Street  ...          200.0
# 3                              Khách sạn Lotus Central  ...          546.0
# 4    Khách sạn Winston Riverside (Hotel Winston Riv...  ...           32.0
# ..                                                 ...  ...            ...
# 465                 Khách sạn Mường Thanh Grand Hà Nội  ...            0.0
# 466                             Silk Queen Grand Hotel  ...            0.0
# 467                                    A25 Hotel & Spa  ...           20.0
# 468                            Dream Hotel & Apartment  ...           35.0
# 469  Khách sạn Lenid De Hồ Gươm\n(Lenid De Ho Guom ...  ...          117.0
#
# [470 rows x 5 columns]

# %%
basic_info.reset_index(inplace=True)
basic_info.rename({'index':'hotel_id', 'stars':'star'}, axis='columns', inplace=True)
basic_info['hotel_id'] = basic_info['hotel_id'] + 1
basic_info
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      hotel_id  ... number_review
# 0           1  ...          56.0
# 1           2  ...         148.0
# 2           3  ...         200.0
# 3           4  ...         546.0
# 4           5  ...          32.0
# ..        ...  ...           ...
# 465       466  ...           0.0
# 466       467  ...           0.0
# 467       468  ...          20.0
# 468       469  ...          35.0
# 469       470  ...         117.0
#
# [470 rows x 6 columns]

# %%
cols = ['price', 'rating', 'number_review']
basic_info[cols].describe()
# Out:
#               price      rating  number_review
# count  4.700000e+02  467.000000     470.000000
# mean   8.458169e+05    8.248608     215.912766
# std    1.296243e+06    0.785308     290.799858
# min    4.553700e+04    5.000000       0.000000
# 25%    3.501360e+05    7.800000      19.000000
# 50%    5.244210e+05    8.500000      89.000000
# 75%    8.098810e+05    8.800000     295.750000
# max    1.000000e+07    9.900000    1836.000000

# %% [markdown]
# # Evaluate overall_score

# %%
a, b, c = 50000, -1, 2500 
basic_info['overall_score'] = a*basic_info['rating'] + b*basic_info['price'] + c*basic_info['number_review']

ranking = basic_info.sort_values('overall_score', ascending=False)
ranking
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      hotel_id  ... overall_score
# 108       109  ...     4716602.0
# 30         31  ...     3930299.0
# 184       185  ...     3613030.0
# 29         30  ...     3268550.0
# 33         34  ...     3113182.0
# ..        ...  ...           ...
# 283       284  ...    -9522500.0
# 340       341  ...    -9650000.0
# 384       385  ...           NaN
# 397       398  ...           NaN
# 441       442  ...           NaN
#
# [470 rows x 7 columns]

# %% [markdown]
# # Result

# %%
ranking = ranking.reset_index(drop=True).reset_index()
ranking.drop({'overall_score'}, axis=1, inplace=True)
ranking.rename({'index':'rank'}, axis=1, inplace=True)
ranking['rank'] = ranking['rank'] + 1
ranking
# Out:
#      rank  hotel_id  ... rating  number_review
# 0       1       109  ...    7.9         1836.0
# 1       2        31  ...    9.1         1516.0
# 2       3       185  ...    8.1         1482.0
# 3       4        30  ...    8.7         1274.0
# 4       5        34  ...    7.2         1206.0
# ..    ...       ...  ...    ...            ...
# 465   466       284  ...    8.8           15.0
# 466   467       341  ...    7.0            0.0
# 467   468       385  ...    NaN            0.0
# 468   469       398  ...    NaN            0.0
# 469   470       442  ...    NaN            0.0
#
# [470 rows x 7 columns]

# %%
# dir = '/content/drive/MyDrive/HUST/20202/Tích hợp dữ liệu/data/ranking.csv'

# ranking.to_csv(dir, index=False)
